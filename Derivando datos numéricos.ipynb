# %%
# %run lib_filelector.ipynb #Asi importamos el otro archivo.
# Out:
# Proceso terminado. Biblioteca cargada. ☠

# %%
datos_numericos = leer_archivo_2col("datos_desde_el_celular.csv")
plot(datos_numericos[0,:], datos_numericos[1,:])
show()

# %%
D_mis_datos = derivar_f(datos_numericos[0,:], datos_numericos[1,:])

# %%
plot(datos_numericos[0,:], D_mis_datos)
grid()
show()
