# %%
from pylab import *
x = linspace(0,pi,10)
y = sin(x)

# %%
plot(x,y, 'o')
show()

# %%
def primitiva(x,y):
    N, h = int((len(x)+1)/2)+1, x[1] - x[0]
    x_bar,  y_bar = zeros(N), zeros(N) 
    x_bar[0], x_bar[1] = x[0], x[1]
    
    for i in range(2, N):
        x_bar[i] = x[2*i-1]
    y_bar[1] = (251/720)*y[0] + (323/360)*y[1] + (-11/30)*y[2] + (53/360)*y[3] + (-19/720)*y[4]
    #for i in range(N-1):
    # y_bar[i+1] =   
    return x_bar, y_bar*h

x_prim, y_prim = primitiva(x,y)

x, x_prim, y_prim
# Out:
# (array([0.        , 0.34906585, 0.6981317 , 1.04719755, 1.3962634 ,
#         1.74532925, 2.0943951 , 2.44346095, 2.7925268 , 3.14159265]),
#  array([0.        , 0.34906585, 1.04719755, 1.74532925, 2.44346095,
#         3.14159265]),
#  array([0.     , 0.06028, 0.     , 0.     , 0.     , 0.     ]))
